# %%
import pandas as pd

# %%
#list
l = [9,8,7,6,5,4,3,2,1]

# %%
type(l)
# Out:
# list

# %%
l
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
#list to series making
s1 = pd.Series(l)

# %%
print(s1)
# Out:
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# 5    4
# 6    3
# 7    2
# 8    1
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
#series to dataframe making
df1 = pd.DataFrame(s1,columns = ['Num'])

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#    Num
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# 5    4
# 6    3
# 7    2
# 8    1

# %%
#list to dataframe making
df2 = pd.DataFrame(l,columns = ['Num'])

# %%
df2
# Out:
#    Num
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# 5    4
# 6    3
# 7    2
# 8    1

# %%
#dataframe to series
s2 = df2['Num']

# %%
s2
# Out:
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# 5    4
# 6    3
# 7    2
# 8    1
# Name: Num, dtype: int64

# %%
type(s2)
# Out:
# pandas.core.series.Series

# %%
#making list with multiple column
li = [[1,2,3],
      [4,5,6],
      [7,8,9]]

# %%
li
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
#list(with multiple column) to dataframe making
df3 = pd.DataFrame(li,columns = ['Num1','Num2','Num3'])

# %%
df3
# Out:
#    Num1  Num2  Num3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %%
#dataframe (with multiple column) to series
s3 = df3[['Num1','Num2']]
s3
# Out:
#    Num1  Num2
# 0     1     2
# 1     4     5
# 2     7     8

# %%
s4 = df3['Num3']
s4
# Out:
# 0    3
# 1    6
# 2    9
# Name: Num3, dtype: int64

# %%
type(s3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(s4)
# Out:
# pandas.core.series.Series
