# %%
import pandas as pd

# %%
#making a dictionary
d = {
    "Name" : ['Kohin','Saidad','Sehrish'],
    "Age"  : [22,5,4],
    "Height" : [5.10,3.5,3.4]
}

# %%
d
# Out:
# {'Name': ['Kohin', 'Saidad', 'Sehrish'],
#  'Age': [22, 5, 4],
#  'Height': [5.1, 3.5, 3.4]}

# %%
type(d)
# Out:
# dict

# %%
#making series from dictionary
s = pd.Series(d['Name'],name = 'Name')

# %%
s
# Out:
# 0      Kohin
# 1     Saidad
# 2    Sehrish
# Name: Name, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
#making dataframe from dictionary
data = pd.DataFrame(d)

# %%
data
# Out:
#       Name  Age  Height
# 0    Kohin   22     5.1
# 1   Saidad    5     3.5
# 2  Sehrish    4     3.4

# %%
#making series from the dataframe
age_series = data['Age']

# %%
age_series
# Out:
# 0    22
# 1     5
# 2     4
# Name: Age, dtype: int64

# %%
type(age_series)
# Out:
# pandas.core.series.Series
